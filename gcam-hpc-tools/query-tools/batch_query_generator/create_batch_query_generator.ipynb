# %%
import gcamreader
import create_batch_query_tools as tools
# Define your path to gcam-core
gcam_core_path = "/lustre/home/2501112459/Desktop/GCAM_Workspace/gcam-hpc-PKU/gcam-core"

# %%
regions = tools.read_regions_from_csv(gcam_core_path+"/input/gcamdata/inst/extdata/common/GCAM_region_names.csv")
queries = gcamreader.parse_batch_query(gcam_core_path+"/output/queries/Main_queries.xml")
self_queriers = gcamreader.parse_batch_query("/lustre/home/2501112459/Desktop/GCAM_Workspace/gcam-hpc-PKU/gcam-hpc-tools/query-tools/batch_query_generator/queries_xml/shrwt_query.xml")
queries.extend(self_queriers)
result = tools.select_queries_and_regions(queries, regions)# start selection panel
# Out:
# ...
# Button(button_style='success', description='Confirm Selection', style=ButtonStyle())
# Output()
